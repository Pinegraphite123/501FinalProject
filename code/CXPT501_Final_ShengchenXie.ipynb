# %% [markdown]
# # **Description**

# %% [markdown]
# For the CXPT501 final project, you will explore a large dataset that we simulated and modified based on a clinical trial (PIONEER-HF, ClinicalTrials.gov Identifier: NCT02554890).
#
# In this study, researchers compared the effects of sacubitril/valsartan versus enalapril in stabilized acute heart failure patients with reduced ejection fraction.

# %% [markdown]
# ##*Information included in the dataset*:
#
# *Demographics*
# *   Age
# *   Sex
# *   Race
# *   Ethnicity
#
# *Baseline characteristics*
# *   Height (cm)
# *   Weight (kg)
# *   Smoking history
# *   Pre-treatment NT-proBNP (pg/mL)
# *   Pre-treatment BNP (pg/mL)
#
# *Disease characteristics*
# *   Prior use of ACEi/ARB
# *   Left ventricular ejection fraction (%)
# *   Chronic renal insufficiency
#
# *Intervention*
# *   Sacubitril/valsartan
# *   Enalapril
#
# *Efficacy outcome*
# *   Week 4 NT-proBNP (pg/mL)
# *   Week 8 NT-proBNP (pg/mL)
#
# *Safety outcome*
# *   Symptomatic hypotension
# *   Hyperkalemia
# *   Angioedema
# *   Death

# %% [markdown]
# # **Instructions**

# %% [markdown]
# ## **Data import (6 points)**

# %% [markdown]
# **Import the Python libraries you decide to use here, e.g. Pandas (2 points)**

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Mangul-Lab-USC/CXPT-501-Fall_23/main/Shengchen_Xie.csv")
df.head()
# Out:
#     Age     Sex             Race               Ethnicity  Height (cm)  \
# 0  46.0  Female  Native American  Not Hispanic or Latino        195.0
# 1  27.0    Male        Caucasian      Hispanic or Latino        173.0
# 2  28.0    Male            Other  Not Hispanic or Latino        163.0
# 3  55.0    Male          Unknown  Not Hispanic or Latino        205.0
# 4  22.0    Male            Asian  Not Hispanic or Latino        166.0
#
#    Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 0         67.0         current                         5671.155
# 1        114.0          former                         5956.040
# 2        116.0          former                         5358.508
# 3         80.0         current                         5802.972
# 4         51.0         current                         6532.955
#
#    Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 0                  4236.353                  3164.556
# 1                  4449.162                  3323.524
# 2                  4002.805                  2990.095
# 3                  4334.820                  3238.111
# 4                  4880.117                  3645.447
#
#    Pre-treatment BNP (pg/mL) Prior use of ACEi/ARB  \
# 0                   1524.166                    No
# 1                   1634.386                    No
# 2                   1331.014                    No
# 3                   1718.535                    No
# 4                   1616.218                   Yes
#
#    Left ventricular ejection fraction (%) Chronic renal insufficiency  \
# 0                                  26.854                         Yes
# 1                                  27.696                         Yes
# 2                                  27.281                          No
# 3                                  27.589                          No
# 4                                  36.099                          No
#
#        Group Symptomatic hypotension Hyperkalemia Death
# 0  Enalapril                      No           No    No
# 1  Enalapril                      No           No    No
# 2  Enalapril                      No           No    No
# 3  Enalapril                     Yes           No    No
# 4  Enalapril                      No           No    No

# %% [markdown]
# **Download/load your individual dataset (.csv file) (2 points)**

# %% [markdown]
# We have prepared a dataset for each of you, labeled by name. Please download or directly import your corresponding data file from https://github.com/Mangul-Lab-USC/CXPT-501-Fall_23. Each dataset contains data for 1 million patients, one per row.
#
# For directly importing your file from GitHub to your Colab notebook, click on your assigned file then right-click the Download button. From there, a drop-down menu like below should appear. Select the option that copies the direct link address to your clipboard, then paste it into your notebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **The drop-down menu shown in Google Chrome.** If you use this web browser, click "Copy link address".

# %% [markdown]
# **Display the dataset (2 points)**

# %%
df.head()
# Out:
#     Age     Sex             Race               Ethnicity  Height (cm)  \
# 0  46.0  Female  Native American  Not Hispanic or Latino        195.0
# 1  27.0    Male        Caucasian      Hispanic or Latino        173.0
# 2  28.0    Male            Other  Not Hispanic or Latino        163.0
# 3  55.0    Male          Unknown  Not Hispanic or Latino        205.0
# 4  22.0    Male            Asian  Not Hispanic or Latino        166.0
#
#    Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 0         67.0         current                         5671.155
# 1        114.0          former                         5956.040
# 2        116.0          former                         5358.508
# 3         80.0         current                         5802.972
# 4         51.0         current                         6532.955
#
#    Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 0                  4236.353                  3164.556
# 1                  4449.162                  3323.524
# 2                  4002.805                  2990.095
# 3                  4334.820                  3238.111
# 4                  4880.117                  3645.447
#
#    Pre-treatment BNP (pg/mL) Prior use of ACEi/ARB  \
# 0                   1524.166                    No
# 1                   1634.386                    No
# 2                   1331.014                    No
# 3                   1718.535                    No
# 4                   1616.218                   Yes
#
#    Left ventricular ejection fraction (%) Chronic renal insufficiency  \
# 0                                  26.854                         Yes
# 1                                  27.696                         Yes
# 2                                  27.281                          No
# 3                                  27.589                          No
# 4                                  36.099                          No
#
#        Group Symptomatic hypotension Hyperkalemia Death
# 0  Enalapril                      No           No    No
# 1  Enalapril                      No           No    No
# 2  Enalapril                      No           No    No
# 3  Enalapril                     Yes           No    No
# 4  Enalapril                      No           No    No

# %% [markdown]
# ## **Data cleaning (16 points)**

# %% [markdown]
# **Please remove all rows that have any NaN value in them (2 points)**
#
# You can confirm that you've done this properly by using:
# ```
# DataFrame.isnull().sum()
# ```

# %%
df.isnull().sum()
# Out:
# Age                                       0
# Sex                                       0
# Race                                      0
# Ethnicity                                 0
# Height (cm)                               0
# Weight (kg)                               0
# Smoking history                           2
# Pre-treatment NT-proBNP (pg/mL)           2
# Week 4 NT-proBNP (pg/mL)                  0
# Week 8 NT-proBNP (pg/mL)                  0
# Pre-treatment BNP (pg/mL)                 0
# Prior use of ACEi/ARB                     0
# Left ventricular ejection fraction (%)    1
# Chronic renal insufficiency               0
# Group                                     0
# Symptomatic hypotension                   1
# Hyperkalemia                              0
# Death                                     0
# dtype: int64

# %%
df_cleaned = df.dropna(how="any")
df_cleaned.isnull().sum()
len(df_cleaned)
# Out:
# 994

# %% [markdown]
# **Based on the study's inclusion criteria, please filter out patients who don't meet the following criteria. Store the remaining patient data in a new DataFrame. (8 points)**
#
# *Inclusion criteria*
# *   age >= 18
# *   pre-treatment NT-proBNP >= 1600 pg/mL
# *   pre-treatment BNP >= 400 pg/mL
# *   left ventricular ejection fraction <= 40%
#
# You can confirm how many patient entries remain by using:
# ```
# len(DataFrame)
# ```

# %%
dff = df.loc[(df['Age']>=18) & (df['Pre-treatment BNP (pg/mL)']>=400) & (df['Pre-treatment NT-proBNP (pg/mL)']>=1600) & (df['Left ventricular ejection fraction (%)']<=40)]
len(dff)
dff.head()
# Out:
#     Age     Sex             Race               Ethnicity  Height (cm)  \
# 0  46.0  Female  Native American  Not Hispanic or Latino        195.0
# 1  27.0    Male        Caucasian      Hispanic or Latino        173.0
# 2  28.0    Male            Other  Not Hispanic or Latino        163.0
# 3  55.0    Male          Unknown  Not Hispanic or Latino        205.0
# 4  22.0    Male            Asian  Not Hispanic or Latino        166.0
#
#    Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 0         67.0         current                         5671.155
# 1        114.0          former                         5956.040
# 2        116.0          former                         5358.508
# 3         80.0         current                         5802.972
# 4         51.0         current                         6532.955
#
#    Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 0                  4236.353                  3164.556
# 1                  4449.162                  3323.524
# 2                  4002.805                  2990.095
# 3                  4334.820                  3238.111
# 4                  4880.117                  3645.447
#
#    Pre-treatment BNP (pg/mL) Prior use of ACEi/ARB  \
# 0                   1524.166                    No
# 1                   1634.386                    No
# 2                   1331.014                    No
# 3                   1718.535                    No
# 4                   1616.218                   Yes
#
#    Left ventricular ejection fraction (%) Chronic renal insufficiency  \
# 0                                  26.854                         Yes
# 1                                  27.696                         Yes
# 2                                  27.281                          No
# 3                                  27.589                          No
# 4                                  36.099                          No
#
#        Group Symptomatic hypotension Hyperkalemia Death
# 0  Enalapril                      No           No    No
# 1  Enalapril                      No           No    No
# 2  Enalapril                      No           No    No
# 3  Enalapril                     Yes           No    No
# 4  Enalapril                      No           No    No

# %% [markdown]
# **Add a "BMI (kg/m^2)" column to the dataframe by calculating body mass index based on weight and height provided** `BMI = weight(kg)/(height(m)**2)` **where** '`**`' **is  the exponent operator in Python. Be wary of units. (6 points)**

# %%
bmi = dff['Weight (kg)']/(dff['Height (cm)']/100)**2
dff['BMI'] = bmi
dff.head()
# Out:
# <ipython-input-6-f6e6bdbc2322>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['BMI'] = bmi
#     Age     Sex             Race               Ethnicity  Height (cm)  \
# 0  46.0  Female  Native American  Not Hispanic or Latino        195.0
# 1  27.0    Male        Caucasian      Hispanic or Latino        173.0
# 2  28.0    Male            Other  Not Hispanic or Latino        163.0
# 3  55.0    Male          Unknown  Not Hispanic or Latino        205.0
# 4  22.0    Male            Asian  Not Hispanic or Latino        166.0
#
#    Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 0         67.0         current                         5671.155
# 1        114.0          former                         5956.040
# 2        116.0          former                         5358.508
# 3         80.0         current                         5802.972
# 4         51.0         current                         6532.955
#
#    Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 0                  4236.353                  3164.556
# 1                  4449.162                  3323.524
# 2                  4002.805                  2990.095
# 3                  4334.820                  3238.111
# 4                  4880.117                  3645.447
#
#    Pre-treatment BNP (pg/mL) Prior use of ACEi/ARB  \
# 0                   1524.166                    No
# 1                   1634.386                    No
# 2                   1331.014                    No
# 3                   1718.535                    No
# 4                   1616.218                   Yes
#
#    Left ventricular ejection fraction (%) Chronic renal insufficiency  \
# 0                                  26.854                         Yes
# 1                                  27.696                         Yes
# 2                                  27.281                          No
# 3                                  27.589                          No
# 4                                  36.099                          No
#
#        Group Symptomatic hypotension Hyperkalemia Death        BMI
# 0  Enalapril                      No           No    No  17.619987
# 1  Enalapril                      No           No    No  38.090147
# 2  Enalapril                      No           No    No  43.659904
# 3  Enalapril                     Yes           No    No  19.036288
# 4  Enalapril                      No           No    No  18.507766

# %% [markdown]
# ## **Data visualization (64 points)**

# %% [markdown]
# ###**Explore the baseline characteristics among sacubitril/valsartan and enalapril groups (14 points)**

# %% [markdown]
# **Categorical Data**
# *   Based on your judgement, use one or more of the most appropriate plot types to visualize some aspect of the categorical data. Intervention type must be distinguished by hue.
# *   Make the following aesthetic changes to your plot as you see fit to make the visualization better:
#
#     ・Use one of Seaborn's Plot-Styles
#
#     ・Use one of Seaborn's Plot-Contexts
#
#     ・Despine your plot
# * Save the plot you make in vector form (.pdf). Use `bbox_inches='tight'` when you do this.

# %%
# categorical data: sex, race, ethnicity, smoking history, prior use of ACEi/ARB, Chronic renal insufficiency, group, symptomatic hypotension, hyperkalemia, death
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# set_context paper, notebook, talk, poster
# set_style darkgrid, whitegrid, dark, white, ticks

# %%
# bmi vs race
# violin and boxplot

sns.set_context("paper")
sns.set_style("ticks")

ax = sns.violinplot(data=dff, x=dff["Race"], y=dff["BMI"], hue=dff["Group"], split=True)
ax = sns.boxplot(data=dff, x=dff["Race"], y=dff["BMI"], hue=dff["Group"], fliersize=0, whis=0)

# removing duplicate legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax = sns.despine()

# plt.savefig("/content/cat_plot.pdf", bbox_inches='tight')

# %% [markdown]
# ###**Explore the efficacy of sacubitril/valsartan and enalapril at 4 weeks and 8 weeks (36 points)**
# **Relational Data**
# *   Follow the steps below to visualize NT-proBNP concentrations over time with a relational-type plot.
# *   Make the following aesthetic changes to your plot as you see fit to make the visualization better:
#
#     ・Use one of Seaborn's Plot-Styles
#
#     ・Use one of Seaborn's Plot-Contexts
#
#     ・Despine your plot
# * Save the plot you make in vector form (.pdf). Use `bbox_inches='tight'` when you do this.

# %% [markdown]
# 1) Subset the cleaned and filtered DataFrame into three smaller DataFrames containing the following columns (8 points):
# *   Pre-treatment NT-proBNP & Intervention Group
# *   Week 4 NT-proBNP & Intervention Group
# *   Week 8 NT-proBNP & Intervention Group

# %%
dff
# Out:
#       Age     Sex              Race               Ethnicity  Height (cm)  \
# 0    46.0  Female   Native American  Not Hispanic or Latino        195.0
# 1    27.0    Male         Caucasian      Hispanic or Latino        173.0
# 2    28.0    Male             Other  Not Hispanic or Latino        163.0
# 3    55.0    Male           Unknown  Not Hispanic or Latino        205.0
# 4    22.0    Male             Asian  Not Hispanic or Latino        166.0
# ..    ...     ...               ...                     ...          ...
# 994  36.0  Female  Pacific Islander      Hispanic or Latino        193.0
# 995  63.0  Female  Pacific Islander  Not Hispanic or Latino        206.0
# 996  55.0    Male         Caucasian      Hispanic or Latino        163.0
# 997  55.0    Male             Asian  Not Hispanic or Latino        208.0
# 999  37.0    Male         Caucasian      Hispanic or Latino        209.0
#
#      Weight (kg) Smoking history  Pre-treatment NT-proBNP (pg/mL)  \
# 0           67.0         current                         5671.155
# 1          114.0          former                         5956.040
# 2          116.0          former                         5358.508
# 3           80.0         current                         5802.972
# 4           51.0         current                         6532.955
# ..           ...             ...                              ...
# 994         95.0         current                         5824.486
# 995         60.0         current                         5279.032
# 996         68.0           never                         6109.584
# 997         82.0           never                         5358.100
# 999         67.0         current                         5840.956
#
#      Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)  \
# 0                    4236.353                  3164.556
# 1                    4449.162                  3323.524
# 2                    4002.805                  2990.095
# 3                    4334.820                  3238.111
# 4                    4880.117                  3645.447
# ..                        ...                       ...
# 994                  3104.451                  1654.672
# 995                  2813.724                  1499.715
# 996                  3256.408                  1735.665
# 997                  2855.867                  1522.177
# 999                  3113.230                  1659.352
#
#      Pre-treatment BNP (pg/mL) Prior use of ACEi/ARB  \
# 0                     1524.166                    No
# 1                     1634.386                    No
# 2                     1331.014                    No
# 3                     1718.535                    No
# 4                     1616.218                   Yes
# ..                         ...                   ...
# 994                   2005.650                    No
# 995                   1478.348                   Yes
# 996                   1424.148                   Yes
# 997                   1342.082                    No
# 999                   1674.825                    No
#
#      Left ventricular ejection fraction (%) Chronic renal insufficiency  \
# 0                                    26.854                         Yes
# 1                                    27.696                         Yes
# 2                                    27.281                          No
# 3                                    27.589                          No
# 4                                    36.099                          No
# ..                                      ...                         ...
# 994                                  33.853                         Yes
# 995                                  25.265                         Yes
# 996                                  31.736                          No
# 997                                  28.337                          No
# 999                                  36.146                          No
#
#                     Group Symptomatic hypotension Hyperkalemia Death  \
# 0               Enalapril                      No           No    No
# 1               Enalapril                      No           No    No
# 2               Enalapril                      No           No    No
# 3               Enalapril                     Yes           No    No
# 4               Enalapril                      No           No    No
# ..                    ...                     ...          ...   ...
# 994  Sacubitril-valsartan                      No           No    No
# 995  Sacubitril-valsartan                      No          Yes    No
# 996  Sacubitril-valsartan                     Yes           No    No
# 997  Sacubitril-valsartan                      No           No    No
# 999  Sacubitril-valsartan                      No           No    No
#
#            BMI
# 0    17.619987
# 1    38.090147
# 2    43.659904
# 3    19.036288
# 4    18.507766
# ..         ...
# 994  25.504040
# 995  14.138939
# 996  25.593737
# 997  18.953402
# 999  15.338477
#
# [903 rows x 19 columns]

# %%
dfpre = dff[['Pre-treatment NT-proBNP (pg/mL)', "Group"]]
dfw4 = dff[["Week 4 NT-proBNP (pg/mL)", "Group"]]
dfw8 = dff[["Week 8 NT-proBNP (pg/mL)", "Group"]]
dfpre
dfw8
# Out:
#      Week 8 NT-proBNP (pg/mL)                 Group
# 0                    3164.556             Enalapril
# 1                    3323.524             Enalapril
# 2                    2990.095             Enalapril
# 3                    3238.111             Enalapril
# 4                    3645.447             Enalapril
# ..                        ...                   ...
# 994                  1654.672  Sacubitril-valsartan
# 995                  1499.715  Sacubitril-valsartan
# 996                  1735.665  Sacubitril-valsartan
# 997                  1522.177  Sacubitril-valsartan
# 999                  1659.352  Sacubitril-valsartan
#
# [903 rows x 2 columns]

# %% [markdown]
# 2) Add a column to each of the three new DataFrames specifying each DataFrame's timepoint. The name of the column should be the same for each DataFrame (6 points).

# %%
time_pre = "0w"
time_4w = "4w"
time_8w = "8w"

dfpre["Timeframe"] = time_pre
dfw4["Timeframe"] = time_4w
dfw8["Timeframe"] = time_8w
# Out:
# <ipython-input-12-c2fb7a10f694>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfpre["Timeframe"] = time_pre
# <ipython-input-12-c2fb7a10f694>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfw4["Timeframe"] = time_4w
# <ipython-input-12-c2fb7a10f694>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfw8["Timeframe"] = time_8w

# %% [markdown]
# 3) Merge all three of the new DataFrames via the most appropriate method. (6 points)

# %%
merged1 = dfpre.merge(dfw4, how="outer")
dfm = merged1.merge(dfw8, how="outer")
dfm
# Out:
#       Pre-treatment NT-proBNP (pg/mL)                 Group Timeframe  \
# 0                            5671.155             Enalapril        0w
# 1                            5956.040             Enalapril        0w
# 2                            5358.508             Enalapril        0w
# 3                            5802.972             Enalapril        0w
# 4                            6532.955             Enalapril        0w
# ...                               ...                   ...       ...
# 2704                              NaN  Sacubitril-valsartan        8w
# 2705                              NaN  Sacubitril-valsartan        8w
# 2706                              NaN  Sacubitril-valsartan        8w
# 2707                              NaN  Sacubitril-valsartan        8w
# 2708                              NaN  Sacubitril-valsartan        8w
#
#       Week 4 NT-proBNP (pg/mL)  Week 8 NT-proBNP (pg/mL)
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 2704                       NaN                  1654.672
# 2705                       NaN                  1499.715
# 2706                       NaN                  1735.665
# 2707                       NaN                  1522.177
# 2708                       NaN                  1659.352
#
# [2709 rows x 5 columns]

# %% [markdown]
# 4 ) Fill in any NaNs in the merged DataFrame with the integer value 0. (2 points)

# %%
dfm = dfm.fillna(0)

# %% [markdown]
# 5) Combine all the columns containing NT-proBNP concentration data into a new, single column. (6 points)

# %%
treatmentvalue = dfm["Pre-treatment NT-proBNP (pg/mL)"] + dfm["Week 4 NT-proBNP (pg/mL)"] + dfm["Week 8 NT-proBNP (pg/mL)"]

dfm["NT-proBNP concentration"] = treatmentvalue
dfm.drop(columns=["Pre-treatment NT-proBNP (pg/mL)", "Week 4 NT-proBNP (pg/mL)", "Week 8 NT-proBNP (pg/mL)"], axis = 1, inplace = True)
dfm
# Out:
#                      Group Timeframe  NT-proBNP concentration
# 0                Enalapril        0w                 5671.155
# 1                Enalapril        0w                 5956.040
# 2                Enalapril        0w                 5358.508
# 3                Enalapril        0w                 5802.972
# 4                Enalapril        0w                 6532.955
# ...                    ...       ...                      ...
# 2704  Sacubitril-valsartan        8w                 1654.672
# 2705  Sacubitril-valsartan        8w                 1499.715
# 2706  Sacubitril-valsartan        8w                 1735.665
# 2707  Sacubitril-valsartan        8w                 1522.177
# 2708  Sacubitril-valsartan        8w                 1659.352
#
# [2709 rows x 3 columns]

# %% [markdown]
# 6) Use a line plot to graph NT-proBNP concentration over time, with Intervention Group seperated by hue. (8 points)
#
# The arguements you pass to lineplot() should include:
# *   `ci='sd'`
# *   `err_style='bars'`
# *   `marker="o"`

# %%
sns.lineplot(data=dfm, x="Timeframe", y="NT-proBNP concentration", hue="Group", errorbar="sd", err_style='bars', marker="o")
# Out:
# <Axes: xlabel='Timeframe', ylabel='NT-proBNP concentration'>

# %% [markdown]
# ###**Explore the efficacy of sacubitril/valsartan and enalapril for a  demographic (8 points)**

# %% [markdown]
# **Matrix Data**
# *   Follow the steps below to produce a heatmap to visualize NT-proBNP concentration at Week 8 for some demographic of your choice. Intervention type must be an axis of the matrix data.
# *   Make the following aesthetic changes to your plot as you see fit to make the visualization better:
#
#     ・Use one of Seaborn's Plot-Contexts
#
# * Save the plot you make in vector form (.pdf). Use `bbox_inches='tight'` when you do this.

# %% [markdown]
# 1) Convert your categorical data into matrix data. (4 points)

# %%
w8c = dff[["Age", "Week 8 NT-proBNP (pg/mL)", "Group"]]
w8c
# Out:
#       Age  Week 8 NT-proBNP (pg/mL)                 Group
# 0    46.0                  3164.556             Enalapril
# 1    27.0                  3323.524             Enalapril
# 2    28.0                  2990.095             Enalapril
# 3    55.0                  3238.111             Enalapril
# 4    22.0                  3645.447             Enalapril
# ..    ...                       ...                   ...
# 994  36.0                  1654.672  Sacubitril-valsartan
# 995  63.0                  1499.715  Sacubitril-valsartan
# 996  55.0                  1735.665  Sacubitril-valsartan
# 997  55.0                  1522.177  Sacubitril-valsartan
# 999  37.0                  1659.352  Sacubitril-valsartan
#
# [903 rows x 3 columns]

# %%
w8c.set_index("Age", drop=False, inplace=True)
ww = w8c.pivot("Group", "Week 8 NT-proBNP (pg/mL)",)
ww
# Out:
# <ipython-input-28-060c1c29a182>:5: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   ww = w8c.pivot("Group", "Week 8 NT-proBNP (pg/mL)",)
#                               Age                                      \
# Week 8 NT-proBNP (pg/mL) 1485.240 1486.083 1487.854 1488.671 1488.856
# Group
# Enalapril                     NaN      NaN      NaN      NaN      NaN
# Sacubitril-valsartan         50.0     69.0     41.0     66.0     68.0
#
#                                                                        ...  \
# Week 8 NT-proBNP (pg/mL) 1488.999 1489.033 1489.789 1491.512 1492.770  ...
# Group                                                                  ...
# Enalapril                     NaN      NaN      NaN      NaN      NaN  ...
# Sacubitril-valsartan         29.0     37.0     29.0     46.0     42.0  ...
#
#                                                                        \
# Week 8 NT-proBNP (pg/mL) 4430.160 4447.170 4471.216 4483.686 4491.363
# Group
# Enalapril                    65.0     53.0     60.0     52.0     29.0
# Sacubitril-valsartan          NaN      NaN      NaN      NaN      NaN
#
#
# Week 8 NT-proBNP (pg/mL) 4492.799 4627.852 4645.769 4783.256 4801.405
# Group
# Enalapril                    23.0     45.0     37.0     77.0     38.0
# Sacubitril-valsartan          NaN      NaN      NaN      NaN      NaN
#
# [2 rows x 903 columns]

# %% [markdown]
# 2) Plot a heatmap from your matrix data. It is okay if it does not look very complex. (4 points)

# %%
sns.heatmap(ww)
# Out:
# <Axes: xlabel='None-Week 8 NT-proBNP (pg/mL)', ylabel='Group'>

# %% [markdown]
# ## **Statistical analysis (20 points)**

# %% [markdown]
# **Explore the safety of sacubitril/valsartan and enalapril in this stabilized acute heart failure patient population**

# %% [markdown]
# Please provide the following statistical measures for various characteristics, including BMI, and group the results by the intervention type (sacubitril/valsartan and enalapril):
#
# **For Sacubitril/Valsartan Intervention:**
#
# Mean and standard deviation (std) for each characteristic, including BMI.
# Median for each characteristic, including BMI.
#
# **For Enalapril Intervention:**
#
# Mean and standard deviation (std) for each characteristic, including BMI.
# Median for each characteristic, including BMI.  (4 points)

# %%
sv = dff.loc[dff["Group"] == "Sacubitril-valsartan"]
sv["BMI"].mean()
sv["BMI"].std()
sv["BMI"].median()

en = dff.loc[dff["Group"] == "Enalapril"]
en["BMI"].mean()
en["BMI"].std()
en["BMI"].median()

mms = {'Sacubitril-valsartan':[sv["BMI"].mean(), sv["BMI"].std(), sv["BMI"].median()], 'Enalapril':[en["BMI"].mean(), en["BMI"].std(), en["BMI"].median()]}
mmstable = pd.DataFrame(data = mms , index = ["Mean", "Std", "Median"])
mmstable
# Out:
#         Sacubitril-valsartan  Enalapril
# Mean               24.723987  25.487781
# Std                 8.756087   8.974260
# Median             24.253479  24.468971

# %% [markdown]
# What statistical test should be employed to analyze the effectiveness of the new heart failure medication formulations developed by two pharmaceutical companies, sacubitril and enalapril, with respect to their claims of reducing NT-proBNP levels? The claims state that sacubitril reduces NT-proBNP levels by an average of 3000 within 4 weeks and 2000 within 8 weeks, while enalapril reduces NT-proBNP levels by an average of 2500 within 4 weeks and 1500 within 8 weeks. A clinical trial was conducted using samples from both companies, and the objective is to determine which formulation is more effective.
#
# Clearly state your hypotheses for the combinations of analyses and do the significance test accordingly:
#
# 1. For the sacubitril group, is there a significant difference between pre-treatment and Week 4 NT-proBNP levels? (2 Points)
#
# 2. For the sacubitril group, is there a significant difference between pre-treatment and Week 8 NT-proBNP levels? (2 Points)
#
# 3. For the enalapril group, is there a significant difference between pre-treatment and Week 4 NT-proBNP levels? (2 Points)
#
# 4. For the enalapril group, is there a significant difference between pre-treatment and Week 8 NT-proBNP levels? (2 Points)
#
# 5. Is there a significant difference in NT-proBNP levels at Week 4 between the two groups (sacubitril and enalapril)? (2 Points)
#
# 6. Is there a significant difference in NT-proBNP levels at Week 8 between the two groups (sacubitril and enalapril)? (2 Points)
#
# 7. Among participants aged 60 or older, is there a significant difference in NT-proBNP levels at Week 4 between the two groups (sacubitril and enalapril)? (2 Points)
#
# 8. Among participants aged 60 or older, is there a significant difference in NT-proBNP levels at Week 8 between the two groups (sacubitril and enalapril)? (2 Points)

# %%
svw = sv[["Pre-treatment NT-proBNP (pg/mL)", "Week 4 NT-proBNP (pg/mL)", "Week 8 NT-proBNP (pg/mL)"]]
svw.reset_index(drop=True, inplace=True)
svw

# %%
# paired t test
# H0: population mean of week 0 NT-proBNP level = that of week 4
# H1: population mean of week 0 NT-proBNP level != that of week 4

import scipy.stats as stats
stats.ttest_rel(svw["Pre-treatment NT-proBNP (pg/mL)"], svw["Week 4 NT-proBNP (pg/mL)"], alternative = 'two-sided')

# reject H
# Out:
# TtestResult(statistic=196.71608675181807, pvalue=0.0, df=451)

# %%
# paired t test
# H0: population mean of week 0 NT-proBNP level = that of week 8
# H1: population mean of week 0 NT-proBNP level != that of week 8

stats.ttest_rel(svw["Pre-treatment NT-proBNP (pg/mL)"], svw["Week 8 NT-proBNP (pg/mL)"], alternative = 'two-sided')

# reject H0
# Out:
# TtestResult(statistic=196.71608347853422, pvalue=0.0, df=451)

# %%
enw = en[["Pre-treatment NT-proBNP (pg/mL)", "Week 4 NT-proBNP (pg/mL)", "Week 8 NT-proBNP (pg/mL)"]]
enw

# %%
# paired t test
# H0: population mean of week 0 NT-proBNP level = that of week 4
# H1: population mean of week 0 NT-proBNP level != that of week 4

stats.ttest_rel(enw["Pre-treatment NT-proBNP (pg/mL)"], enw["Week 4 NT-proBNP (pg/mL)"], alternative = 'two-sided')

# reject H0
# Out:
# TtestResult(statistic=183.70660701336666, pvalue=0.0, df=450)

# %%
# paired t test
# H0: population mean of week 0 NT-proBNP level = that of week 4
# H1: population mean of week 0 NT-proBNP level != that of week 4

stats.ttest_rel(enw["Pre-treatment NT-proBNP (pg/mL)"], enw["Week 8 NT-proBNP (pg/mL)"], alternative = 'two-sided')

# reject H0
# Out:
# TtestResult(statistic=183.706595375935, pvalue=0.0, df=450)

# %%
# independent sample t test
# H0: population mean of the two treatment group at week 4 is equal
# H1: population mean of the two treatment group at week 4 is not equal

stats.levene(sv["Week 4 NT-proBNP (pg/mL)"], en["Week 4 NT-proBNP (pg/mL)"])

# unequal variance
stats.ttest_ind(sv["Week 4 NT-proBNP (pg/mL)"], en["Week 4 NT-proBNP (pg/mL)"], alternative = 'two-sided', equal_var=False)

# reject H0
# Out:
# TtestResult(statistic=-44.1575667889505, pvalue=1.062826795512632e-214, df=782.7571457944326)

# %%
# independent sample t test
# H0: population mean of the two treatment group at week 8 is equal
# H1: population mean of the two treatment group at week 8 is not equal

stats.levene(sv["Week 8 NT-proBNP (pg/mL)"], en["Week 8 NT-proBNP (pg/mL)"])

# unequal variance
stats.ttest_ind(sv["Week 8 NT-proBNP (pg/mL)"], en["Week 8 NT-proBNP (pg/mL)"], alternative = 'two-sided', equal_var=False)

# reject H0
# Out:
# TtestResult(statistic=-81.7364334238057, pvalue=0.0, df=642.5900698081673)

# %%
age60 = dff.loc[dff["Age"] >= 60]
age60sv = age60.loc[age60["Group"] == "Sacubitril-valsartan"]
age60en = age60.loc[age60["Group"] == "Enalapril"]

# %%
# independent sample t test
# H0: population mean above age 60 of the two treatment group at week 4 is equal
# H1: population mean above age 60 of the two treatment group at week 4 is not equal

stats.levene(age60sv["Week 4 NT-proBNP (pg/mL)"], age60en["Week 4 NT-proBNP (pg/mL)"])

# unequal variance
stats.ttest_ind(age60sv["Week 4 NT-proBNP (pg/mL)"], age60en["Week 4 NT-proBNP (pg/mL)"], alternative = 'two-sided', equal_var=False)

# reject H0

# to see which group has larger NT-proBNP concentration
stats.ttest_ind(age60sv["Week 4 NT-proBNP (pg/mL)"], age60en["Week 4 NT-proBNP (pg/mL)"], alternative = 'less', equal_var=False)
# age above 60 in sv group has significantly smaller NT-proBNP concentration at week 4 than that of en group
# Out:
# TtestResult(statistic=-25.64672401408371, pvalue=1.1074083192770485e-73, df=261.79360123420355)

# %%
# independent sample t test
# H0: population mean above age 60 of the two treatment group at week 8 is equal
# H1: population mean above age 60 of the two treatment group at week 8 is not equal

stats.levene(age60sv["Week 8 NT-proBNP (pg/mL)"], age60en["Week 8 NT-proBNP (pg/mL)"])

# unequal variance
stats.ttest_ind(age60sv["Week 8 NT-proBNP (pg/mL)"], age60en["Week 8 NT-proBNP (pg/mL)"], alternative = 'two-sided', equal_var=False)

# reject H0

# to see which group has larger NT-proBNP concentration
stats.ttest_ind(age60sv["Week 8 NT-proBNP (pg/mL)"], age60en["Week 8 NT-proBNP (pg/mL)"], alternative = 'less', equal_var=False)
# age above 60 in sv group has significantly smaller NT-proBNP concentration at week 8 than that of en group
# Out:
# TtestResult(statistic=-46.73931114640369, pvalue=4.256157202857119e-115, df=215.60669479387798)

# %% [markdown]
# Is there a statistically significant difference between the pre-treatment NT-proBNP and week 4 NT-proBNP, and between baseline and week 8 NT-proBNP in sacubitril/valsartan and enalapril groups? (2 points)

# %%
# paired t test
# H0: population mean of week 0 NT-proBNP level = that of week 4, regardless of treatment group
# H1: population mean of week 0 NT-proBNP level != that of week 4, regardless of treatment group

stats.ttest_rel(dff["Pre-treatment NT-proBNP (pg/mL)"], dff["Week 4 NT-proBNP (pg/mL)"], alternative = 'two-sided')

# reject H0, significantly different
# Out:
# TtestResult(statistic=94.70188980791465, pvalue=0.0, df=902)

# %%
# paired t test
# H0: population mean of week 0 NT-proBNP level = that of week 8, regardless of treatment group
# H1: population mean of week 0 NT-proBNP level != that of week 8, regardless of treatment group

stats.ttest_rel(dff["Pre-treatment NT-proBNP (pg/mL)"], dff["Week 8 NT-proBNP (pg/mL)"], alternative = 'two-sided')

# reject H0, significantly different
# Out:
# TtestResult(statistic=115.11659313404432, pvalue=0.0, df=902)

# %% [markdown]
# _**[ Write your answer here ]**_

# %% [markdown]
# Upload to github

# %%
# %%bash
# rm -r sample_data

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore

# %%
# %%bash
# git config --global user.email "xiesheng@usc.edu"
# git config --global user.name "xiesheng"

# %%
# %%bash
# git init
# Out:
# Initialized empty Git repository in /content/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %%
# %%bash
# mkdir startingData code result figure

# %%
# %%bash
# cd startingData
# wget "https://raw.githubusercontent.com/Mangul-Lab-USC/CXPT-501-Fall_23/main/Shengchen_Xie.csv"
# Out:
# --2023-12-05 01:01:39--  https://raw.githubusercontent.com/Mangul-Lab-USC/CXPT-501-Fall_23/main/Shengchen_Xie.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 135254 (132K) [text/plain]
# Saving to: ‘Shengchen_Xie.csv’
#
#      0K .......... .......... .......... .......... .......... 37% 15.0M 0s
#     50K .......... .......... .......... .......... .......... 75% 72.9M 0s
#    100K .......... .......... .......... ..                   100% 30.6M=0.005s
#
# 2023-12-05 01:01:40 (26.0 MB/s) - ‘Shengchen_Xie.csv’ saved [135254/135254]

# %%
# %%bash
# cd startingData
# cat > readme.md
# This is the starting data

# %%
# %%bash
# cd figure
# cat > readme.md
# This is the figures requested

# %%
# %%bash
# cd result
# cat > readme.md
# This is the statistical analysis but all of the tests requests return significance

# %%
# %%bash
# cd code
# cat > readme.md
# This is the code

# %% [markdown]
# Save figures and proceed

# %%
# %%bash
# git add -A

# %%
# %%bash
# git commit -m "First commit"

# %%
# %%bash
# ssh-keygen -t ed25519 -C 'xiesheng@usc.edu' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
#   IdentityFile ~/.ssh/id_ed25519

# %%
# %%bash
# cat ~/.ssh/id_ed25519

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub

# %%
# %%bash
# ssh -o "StrictHostKeyChecking no" -T git@github.com | exit 0

# %%
# %%bash
# git remote add origin git@github.com:Pinegraphite123/501FinalProject.git
# git branch -M main
# git push -u origin main
